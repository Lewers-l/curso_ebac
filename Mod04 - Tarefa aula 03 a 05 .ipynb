# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  8
pc_qui = df_qui /  8

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
total_gt_45 = total[total['Qt_acertos'] > 45]
total_gt_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
#1
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]
#2
print(df_eliminados.count())

#3
media_geo = df_eliminados=[(df_geo['Qt_acertos'] / 8)]
media_his = df_eliminados=[(df_his['Qt_acertos'] / 8)]
print(f'{[media_geo,media_his]}')

#4

aprovados = total_gt_45[(df_mat['Qt_acertos'] == 0) | 
                        (df_fis['Qt_acertos'] == 0) | 
                        (df_qui['Qt_acertos'] == 0)]

aprovados
# Out:
# Qt_acertos    23
# dtype: int64
# [[0     0.875
# 1     0.000
# 2     0.000
# 3     0.375
# 4     0.250
#       ...
# 95    0.875
# 96    0.500
# 97    0.000
# 98    0.375
# 99    0.000
# Name: Qt_acertos, Length: 100, dtype: float64], [0     0.125
# 1     0.000
# 2     0.875
# 3     0.000
# 4     0.000
#       ...
# 95    0.500
# 96    0.125
# 97    0.500
# 98    0.625
# 99    0.750
# Name: Qt_acertos, Length: 100, dtype: float64]]
# <ipython-input-8-792fb8796b08>:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   aprovados = total_gt_45[(df_mat['Qt_acertos'] == 0) |
#     Qt_acertos
# 20          53
# 27          50
# 35          48
# 72          50
# 89          63

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = './racre.csv'

# %%
# 1) Sua solução aqui
df = pd.read_csv(arquivo, sep=';')

# %%
df.head(30)
# Out:
#                                   document_id  \
# 0   b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1   a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2   af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3   4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4   000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# 5   13dac96a-cdab-49a8-8c2a-0341c8b2638c-i0b0
# 6   852365aa-108b-4aa2-ae39-7b5d46149678-i0b0
# 7   9ef6e305-609d-4e4e-a0c2-e43a8139922d-i0b0
# 8   005c7f34-2539-4d3a-895d-60abdd1dde10-i0b0
# 9   6b980351-362b-4e1c-9cda-a9449fa01fed-i0b0
# 10  0076f33b-9d20-4323-ae56-869a860330aa-i0b0
# 11  ca387e50-a362-4c05-ad14-e090b94969f3-i0b0
# 12  b38d3e09-0d4f-41aa-8427-4e1578997c31-i0b0
# 13  67169ef3-524f-4c7a-aadd-83e716608baf-i0b0
# 14  5d250c76-7f37-4326-9b08-1940fe0fd88e-i0b0
# 27  cb76143ebb47baefcafe0ab39bfd70e9464e9170838781...              35
# 28  46307f1b92737528cc3738257ac8bd115d69dac9204398...              37
# 29  31f03ac927f9fafe738275e80b1e8d14d42f6329d8ba38...              77
#
#    paciente_datanascimento paciente_enumsexobiologico  \
# 0               1951-12-28                          F
# 1               1939-11-22                          M
# 2               1951-08-14                          M
# 3               1969-12-15                          F
# 4               1955-11-21                          M
# 5               1964-05-25                          M
# 6               1955-09-25                          M
# 7               1981-11-02                          M
# 8               1941-06-10                          F
# 9               1998-06-27                          F
# 10              1958-08-12                          M
# 11              1951-12-16                          M
# 12              1959-01-12                          M
# 13              1953-07-14                          M
# 14              1937-10-28                          F
# 15              1965-01-26                          M
# 16              1944-12-11                          F
# 17              1976-05-29                          M
# 18              1933-08-04                          M
# 19              1960-09-15                          M
# 20              1959-12-23                          M
# 21              1993-08-04                          M
# 22              2002-07-21                          F
# 23              1952-08-17                          F
# 24              1922-04-02                          F
# 25              1960-05-29                          M
# 26              1951-05-13                          M
# 27              1986-01-25                          M
# 28              1983-12-29                          F
# 29              1944-03-01                          M
#
#     paciente_racacor_codigo paciente_racacor_valor  \
# 0                         3                  PARDA
# 1                         3                  PARDA
# 2                         4                AMARELA
# 3                         3                  PARDA
# 4                         3                  PARDA
# 5                        99         SEM INFORMACAO
# 6                         4                AMARELA
# 7                         4                AMARELA
# 8                         5               INDIGENA
# 9                         3                  PARDA
# 10                        3                  PARDA
# 11                        3                  PARDA
# 12                        3                  PARDA
# 13                        1                 BRANCA
# 14                        2                  PRETA
# 15                        3                  PARDA
# 16                        5               INDIGENA
# 17                       99         SEM INFORMACAO
# 18                        3                  PARDA
# 19                        1                 BRANCA
# 20                        3                  PARDA
# 21                        4                AMARELA
# 22                        5               INDIGENA
# 23                        3                  PARDA
# 24                        4                AMARELA
# 25                        4                AMARELA
# 26                        4                AMARELA
# 27                        3                  PARDA
# 28                        3                  PARDA
# 29                        3                  PARDA
#
#     paciente_endereco_coibgemunicipio  paciente_endereco_copais  \
# 0                            120050.0                      10.0
# 1                            120040.0                      10.0
# 2                            120020.0                      10.0
# 3                            120040.0                      10.0
# 4                            120040.0                      10.0
# 5                                 NaN                       NaN
# 6                            120050.0                      10.0
# 7                            120020.0                      10.0
# 8                            120005.0                      10.0
# 9                            120020.0                      10.0
# 10                           120040.0                      10.0
# 11                           120010.0                      10.0
# 12                           120020.0                      10.0
# 13                           120040.0                      10.0
# 14                           120040.0                      10.0
# 15                           120040.0                      10.0
# 16                           120033.0                      10.0
# 17                           120040.0                      10.0
# 18                           120001.0                      10.0
# 19                           120005.0                      10.0
# 20                           120040.0                      10.0
# 21                           120060.0                      10.0
# 22                           120043.0                      10.0
# 23                           120039.0                      10.0
# 24                           120040.0                      10.0
# 25                           120013.0                      10.0
# 26                           120040.0                      10.0
# 27                           120005.0                      10.0
# 28                           120040.0                      10.0
# 29                           120040.0                      10.0
#
#    paciente_endereco_nmmunicipio  ...   vacina_lote vacina_fabricante_nome  \
# 0                 SENA MADUREIRA  ...       210052A      FUNDACAO BUTANTAN
# 16   Organization/61189445000156           2021-01-20                1ª Dose
# 17   Organization/61189445000156           2021-04-08                2ª Dose
# 18   Organization/33781055000135           2021-03-04                1ª Dose
# 19   Organization/61189445000156           2021-04-28                2ª Dose
# 20   Organization/33781055000135           2021-04-18                1ª Dose
# 21   Organization/61189445000156           2021-02-20                2ª Dose
# 22   Organization/61189445000156           2021-02-03                1ª Dose
# 23   Organization/61189445000156           2021-04-28                2ª Dose
# 24   Organization/61189445000156           2021-02-12                1ª Dose
# 25   Organization/61189445000156           2021-04-27                2ª Dose
# 26   Organization/33781055000135           2021-03-25                1ª Dose
# 27   Organization/61189445000156           2021-03-19                2ª Dose
# 28   Organization/61189445000156           2021-03-22                1ª Dose
# 29   Organization/61189445000156           2021-04-12                2ª Dose
#
#    vacina_codigo                          vacina_nome  sistema_origem  \
# 0             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 1             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 2             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 3             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 4             85         Vacina Covid-19 - Covishield        Novo PNI
# 5             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 6             85         Vacina Covid-19 - Covishield        Novo PNI
# 7             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 8             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 9             86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 10            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 11            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 12            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 13            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 14            85         Vacina Covid-19 - Covishield        Novo PNI
# 15            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 16            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 17            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 18            85         Vacina Covid-19 - Covishield        Novo PNI
# 19            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 20            85         Vacina Covid-19 - Covishield        Novo PNI
# 21            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 22            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 23            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 24            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 25            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 26            85         Vacina Covid-19 - Covishield        Novo PNI
# 27            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 28            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
# 29            86  Covid-19-Coronavac-Sinovac/Butantan        Novo PNI
#
#         data_importacao_rnds id_sistema_origem
# 0   2021-03-25T03:27:19.000Z               NaN
# 1   2021-04-30T16:03:14.000Z               NaN
# 2   2021-04-16T15:54:39.000Z               NaN
# 3   2021-03-10T14:40:54.000Z               NaN
# 4   2021-04-03T19:44:28.000Z               NaN
# 5   2021-04-12T20:36:34.000Z               NaN
# 6   2021-04-06T16:34:46.000Z               NaN
# 7   2021-02-19T21:53:14.000Z               NaN
# 8   2021-02-05T22:52:20.000Z               NaN
# 9   2021-05-04T12:50:15.000Z               NaN
# 10  2021-04-02T19:46:36.000Z               NaN
# 11  2021-04-23T14:01:23.000Z               NaN
# 12  2021-03-19T16:19:45.000Z               NaN
# 13  2021-04-29T16:02:16.000Z               NaN
# 14  2021-03-04T02:54:36.000Z               NaN
# 15  2021-03-05T16:14:27.000Z               NaN
# 16  2021-02-01T13:48:07.000Z               NaN
# 17  2021-04-12T15:59:54.000Z               NaN
# 18  2021-03-05T15:26:10.000Z               NaN
# 19  2021-04-29T20:55:34.000Z               NaN
# 20  2021-04-19T16:30:01.000Z               NaN
# 21  2021-03-01T16:05:21.000Z               NaN
# 22  2021-02-09T23:52:46.000Z               NaN
# 23  2021-04-29T14:17:27.000Z               NaN
# 24  2021-02-16T20:09:20.000Z               NaN
# 25  2021-04-27T21:21:33.000Z               NaN
# 26  2021-03-31T15:58:30.000Z               NaN
# 27  2021-04-14T16:44:41.000Z               NaN
# 28  2021-03-28T15:13:41.000Z               NaN
# 29  2021-04-13T14:25:12.000Z               NaN
#
# [30 rows x 34 columns]

# %%
df.shape[0]
# Out:
# 169071

# %%
# 2) 
df['paciente_id'].nunique()
# Out:
# 120517

# %%
# 3) 
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 119713

# %%
# 3) solução alternativa
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df[df['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 119713

# %%
# 4) 
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 47

# %%
# 5)
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()

# %%
# 2) 
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem', 'data_importacao_rnds', 'id_sistema_origem'],
#       dtype='object')

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Povos e Comunidades Tradicionais     9
# Trabalhadores de Saúde               9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor.loc[:,lista_variaveis]

# %%
# 5)
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista.shape
# Out:
# (18, 6)
